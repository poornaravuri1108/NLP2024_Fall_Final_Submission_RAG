# %%
from typing import List
import shutil
import os
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings
from langchain_community.document_loaders import PyPDFLoader 
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_chroma import Chroma
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnableMap, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableConfig

# %%
load_dotenv(dotenv_path='.env', verbose=True)
NVIDIA_E5_EMBEDDING_API_KEY = os.getenv('NVIDIA_E5_EMBEDDING_API_KEY')

# %%
def load_documents(DATA_PATH: str) -> List[Document]:
    documents = []
    
    if not os.path.exists(DATA_PATH):
        raise FileNotFoundError(f"Directory not found: {DATA_PATH}")
    
    pdf_files = [f for f in os.listdir(DATA_PATH) if f.endswith('.pdf')]
    print(f"Found {len(pdf_files)} PDF files in {DATA_PATH}")
    
    for filename in pdf_files:
        filepath = os.path.join(DATA_PATH, filename)
        try:
            loader = PyPDFLoader(filepath)
            docs = loader.load()
            
            for doc in docs:
                doc.metadata['source'] = filename
            
            documents.extend(docs)
            print(f"Successfully loaded {len(docs)} pages from {filename}")
            
        except Exception as e:
            print(f"Error loading {filename}: {str(e)}")
    
    return documents

# %%
def split_text(documents: List[Document]) -> List[Document]:
    if not documents:
        raise ValueError("No documents to split")
        
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=100,
        length_function=len,
        is_separator_regex=False,
    )
    
    chunks = text_splitter.split_documents(documents)
    print(f"{len(documents)} documents are split into {len(chunks)} chunks")
    
    chunks = [chunk for chunk in chunks if chunk.page_content.strip()]
    print(f"After removing empty chunks: {len(chunks)} chunks remain")
    
    return chunks

# %%
def save_data_to_db(data_chunks: List[Document], CHROMA_PATH: str):
    if not data_chunks:
        raise ValueError("No chunks to save to database")
        
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)
    
    try:
        # embeddings = NVIDIAEmbeddings(
        #     model="nvidia/nv-embedqa-e5-v5",
        #     api_key=NVIDIA_E5_EMBEDDING_API_KEY,
        #     truncate="NONE"
        # )   
        # embeddings = NVIDIAEmbeddings(
        #     model="nvidia/nv-embedqa-e5-v5", 
        #     api_key="", 
        #     truncate="NONE", 
        # ) 

        embeddings = NVIDIAEmbeddings(
                model="nvidia/nv-embedqa-mistral-7b-v2", 
                api_key="", 
                truncate="NONE", 
                )    
        
        vector_store = Chroma(
            collection_name="NLP_Project_embedding",
            embedding_function=embeddings,
            persist_directory=CHROMA_PATH
        )

        vector_store.add_documents(documents=data_chunks)

        print(f"Saved {len(data_chunks)} chunks to chroma db")
        return vector_store
        
    except Exception as e:
        print(f"Error creating embeddings: {str(e)}")
        raise

# %%
def getEmbeddings(CHROMA_PATH: str, DATA_PATH: str):
    try:
        documents = load_documents(DATA_PATH)
        if not documents:
            raise ValueError("No documents were successfully loaded")
            
        data_chunks = split_text(documents)
        print(f"Length of data chunks is {len(data_chunks)}")
        

        if not data_chunks:
            raise ValueError("No chunks were created from the documents")
                    
        db = save_data_to_db(data_chunks, CHROMA_PATH)
        return db
        
    except Exception as e:
        print(f"Error in getEmbeddings: {str(e)}")
        raise

# %%
if __name__ == "__main__":
    try:
        if not NVIDIA_E5_EMBEDDING_API_KEY:
            raise ValueError("Nvidia embedding api key not found in environment variables")
        else:
            print(f"NVIDIA EMBEDDING API KEY IS {NVIDIA_E5_EMBEDDING_API_KEY}")
            
        CHROMA_PATH = "chroma"
        DATA_PATH = "pdfs/"
        
        os.makedirs(CHROMA_PATH, exist_ok=True)
        
        db = getEmbeddings(CHROMA_PATH, DATA_PATH)
        
        if db is not None:
            test_results = db.similarity_search("test query", k=1)
            print("\nDatabase test successful")
            
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# NVIDIA EMBEDDING API KEY IS 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
# Found 2 PDF files in pdfs/
# Successfully loaded 24 pages from AWS Customer Agreement.pdf
# Successfully loaded 90 pages from AWS Service Terms.pdf
# 114 documents are split into 387 chunks
# After removing empty chunks: 387 chunks remain
# Length of data chunks is 387
# Saved 387 chunks to chroma db
#
# Database test successful

# %%
db.get(
    include = ["embeddings"]
)
# Out:
# {'ids': ['e32b1d09-8bf6-4bd8-8458-c9a09590475d',
#   'a6747cc4-9dd7-4d31-9730-9adfb010d5da',
#   'f5491f31-016c-4571-9158-05e841b3f09a',
#   '81d829fc-eefa-4e85-b306-765ed53151bf',
#   '94f4d005-e56d-4dd2-8ce2-38a311a3ced4',
#   '41628022-9a05-4966-9ff7-7b3cbc1ac7e0',
#   'ae1819b5-3555-47b3-b785-2255a6e09687',
#   '9b69cfc9-a1c0-4b0d-b221-d7ad5150d86d',
#   'ed3125dd-a85e-4a5e-9ea9-68d78e5f0259',
#   '43cf9b12-720b-4375-b16a-540a70e4ce25',
#   'e1e56966-1781-4864-b99a-67c625415b49',
#   '936c9f3f-865d-449f-b9b4-22b60bf55961',
#   '645ec57f-f1c8-454a-91f7-bfc22f98645a',
#   '3a5f1f13-366d-46d4-8e86-eb7549124066',
#   '59b0b200-6e1c-444f-b0b8-5f24d5aa33d2',
#   'a91cb984-fd7a-4486-8eed-0161a5a5b5f3',
#   '31b28c7f-10bb-4c49-91f1-4fc4d88abda9',
#   '5ab72c42-f890-4591-93c9-a1c5aebc7ece',
#   'ff55cf1f-8b4c-471a-b000-99fe70f4f1b5',
#   '29218ae0-daee-4a5e-acf5-d22bf509c90b',
#   'aa53d611-27d0-49e5-90df-92de73f849a6',
#   '49152da3-dc81-4208-bc0d-8ef1cc2f9cf0',
#   '691f0604-2c21-4ccd-abd7-43e407302259',
#   '06c40f55-753d-41f1-ae46-7a351dc3f59b',
#   '0a6a278f-7186-47e0-a57e-79f6b2dfbd51',
#   '384c91db-a154-4f46-b4f4-5c63f40521b7',
#   '238f0bc7-093a-4c7b-ac5c-935a8bd894ab',
#   'bc969db3-6dd1-4b1b-9490-72db41f3c7d6',
#   '20672445-08fa-41f3-b3df-06f24bf48c65',
#   '9eeb1589-60ea-4036-b582-73965b790114',
#   '80bffadd-7245-43ea-87fb-0614f8fb46b1',
#   '7939f804-1c96-4edb-975a-40de6cea7fee',
#   '1600e9a9-b6a6-44db-af8b-9603e55a1b40',
#   '77e56441-4d4e-4ca8-8af9-dbd80746dd62',
#   'f67bcc0d-268c-4550-be43-5c7edab037dc'],
#  'embeddings': array([[ 0.01029205,  0.00398636,  0.01383209, ...,  0.0262146 ,
#           0.01179504,  0.01916504],
#         [ 0.01412201,  0.01522827,  0.01389313, ...,  0.00579834,
#           0.01010895,  0.03060913],
#         [ 0.00808716, -0.00804138,  0.00167751, ...,  0.01194763,
#           0.01258087,  0.01634216],
#         ...,
#         [ 0.03216553, -0.00771332,  0.02565002, ...,  0.0181427 ,
#           0.01593018,  0.00028539],
#         [-0.00235939,  0.01004791,  0.01416016, ...,  0.01591492,
#           0.01733398,  0.00746918],
#         [ 0.00456619,  0.00938416,  0.03543091, ...,  0.00894165,
#           0.00349045,  0.00094271]]),
#  'documents': None,
#  'uris': None,
#  'data': None,
#  'metadatas': None,
#  'included': [<IncludeEnum.embeddings: 'embeddings'>]}

# %%
import chromadb
from chromadb.config import Settings
# Out:
# {'ids': ['4316af71-8a46-4c9c-9bc7-69ba08157555',
#   'bd12e665-ed07-4235-aa95-818cde22808a',
#   '3ca02e7a-de7a-4e96-8e98-5380af33b9c2',
#   '94e18f72-faed-4701-9aff-00d25fbe97c1',
#   '964d7c95-5475-453f-a637-99b1395d2fb4',
#   '6790fc5a-e39a-42ef-af37-d338b9e63b6b',
#   '798a2aca-736b-434e-b22c-3fb3a4fbb789',
#   'd8374e17-7462-41b5-94b8-0b50e7deba16',
#   'e1e4293a-2f06-4c62-93b1-1013ea0eed8f',
#   '6908fabb-c72d-4840-9c61-c655982938e2',
#   '70bf4cce-3c7f-47aa-9819-ad59a700d8b1',
#   'b1c77f3b-ec4a-4851-aeab-583f68d34a92',
#   '8174bdd9-282f-45e1-a9b2-d29550d6c49b',
#   '87017dde-a459-4b48-a38f-320e01bc9cbc',
#   '7b3a82c4-35ab-4674-910a-baebe4fe99d8',
#   '070990a8-80e2-4076-a138-1bedc07e0324',
#   '097a893c-5fa0-48d1-b95e-db3beda57e23',
#   'd8607afb-a1d4-461a-85d9-91361af64e12',
#   '3fcdfbe5-0765-4572-b638-95b5d2eabbad',
#   'd05ff497-c9e2-4ea4-bd41-61c44650f372',
#   '6fe92059-0aaa-4aec-bb98-bd0c69d06bb0',
#   '72907d88-31ce-4fdb-a982-3c1b8d61b15e',
#   'b51f523b-9a66-4bac-ab46-1585e42add7b',
#   '72bb942d-26c9-4803-82c6-bf60c8571445',
#   'fa0f648b-ca85-40fc-a970-e41e7b1e8bf0',
#   'f1747514-f374-4819-842d-80279bc64c4b',
#   '6c58864b-3457-4cd5-81c0-1ec0fc98863e',
#   '2e92400a-d1db-43da-a4ef-96fcf474369a',
#   '6380c5b8-d4c5-47e3-b2ed-639499f1fdeb',
#   '479036fa-0542-47a2-9642-fe1578b48521',
#   'c8d511e5-3c9a-42ea-a0ec-1ef43d7d4afb',
#   '2c5984e7-60b5-43bc-bd7d-117912aad503',
#   '4bd4c1bc-d625-4a3e-af23-5aaf1eea8772',
#   '70e64010-dbb2-415d-bce1-46139da09b85',
#   '1139998b-154e-4b93-ba4e-37f88450e8a0'],
#  'embeddings': None,
#  'documents': ["AWS Customer Agreement\nLast Updated: May 17, 2024\nSee What's Changed\nThis AWS Customer Agreement (this “Agreement”) contains the terms and conditions that govern your access to and use of the Services (as de\x00ned below) and\nis an agreement between the applicable AWS Contracting Party speci\x00ed in Section 12 below (also referred to as “AWS,” “we,” “us,” or “our”) and you or the\nentity you represent (“you” or “your”). This Agreement takes e\x00ect when you click an “I Accept” button or check box presented with these terms or, if earlier,\nwhen you use any of the Services (the “Eﬀective Date”). You represent to us that you are lawfully able to enter into contracts (e.g., you are not a minor). If you\nare entering into this Agreement for an entity, such as the company you work for, you represent to us that you have legal authority to bind that entity. Please\nsee Section 12 for de\x00nitions of certain capitalized terms used in this Agreement.\n1. AWS Responsibilities",
#   '1. AWS Responsibilities\n1.1 General. You may access and use the Services in accordance with this Agreement. Service Level Agreements and Service Terms apply to certain Services.\n**For additional information related to each AWS Contracting Party, see the AWS\xa0Contracting Party FAQs.\n*Please note that as of January 1, 2024, customers located in Türkiye contract with our\xa0Türkiye based AWS Contracting Party, as provided in Section\n12. See the AWS Turkey FAQs for\xa0more information.',
#   '1.2 Third-Party Content. Third-Party Content may be used by you at your election. Third-Party Content is governed by this Agreement and, if applicable,\nseparate terms and conditions accompanying such Third-Party Content, which terms and conditions may include separate fees and charges.\xa0\n1.3\xa0AWS Security. Without limiting Section 8 or your obligations under Section 2.2, we will implement reasonable and appropriate measures designed to help\nyou secure Your Content against accidental or unlawful loss, access or disclosure.\n1.4 Data Privacy.\xa0You may specify the AWS regions in which Your Content will be stored. You consent to the storage of Your Content in, and transfer of Your\nContent into, the AWS regions you select. We will not access or use Your Content except as necessary to maintain or provide the Services, or as necessary to\ncomply with the law or a binding order of a governmental body. We will not (a) disclose Your Content to any government or third party or (b) move Your',
#   'Content from the AWS regions selected by you; except in each case as necessary to comply with the law or a binding order of a governmental body. Unless it\nwould violate the law or a binding order of a governmental body, we will give you notice of any legal requirement or order referred to in this Section 1.4. We\nwill only use your Account Information in accordance with the Privacy Notice, and you consent to such usage. The Privacy Notice does not apply to Your\nContent.\n1.5 Notice of Changes to the Services. We may change or discontinue any of the Services from time to time. We will provide you at least 12 months’ prior\nnotice before discontinuing a material functionality of a Service that\xa0we make generally available to customers and that you are using. AWS will not be\nobligated to provide such notice under this Section 1.5 if the discontinuation is necessary to (a) address an emergency, or risk of harm to the Services or AWS,',
#   '(b) respond to claims, litigation, or loss of license rights related to third party intellectual property rights, or (c) comply with law,\xa0but should any of the\npreceding occur AWS will provide you with as much prior notice as is reasonably practicable under the circumstances.\n1.6 Notice of Changes to the Service Level Agreements. We may change, discontinue or add Service Level Agreements, provided, however, that we will provide\nat least 90 days’ advance notice for adverse changes to any Service Level Agreement.\n2. Your Responsibilities.\n2.1\xa0Your Accounts. You will comply with the terms of this Agreement and all laws, rules and regulations applicable to your use of the Services. To access the\nServices, you must have an AWS account associated with a valid email address and a valid form of payment. Unless\xa0explicitly permitted by the Service Terms,',
#   'you will only create one account per email address. Except to the extent caused by our breach of this Agreement, (a) you are responsible for all activities that\noccur under your account, regardless of whether the activities are authorized by you or undertaken by you, your employees or a third party (including your\ncontractors, agents or End Users), and (b) we and our a\x00liates are not responsible for unauthorized access to your account.',
#   '2.2 Your Content. You are responsible for Your Content. You will ensure that Your Content and your and End Users’ use of Your Content or the Services\xa0will not\nviolate any of the Policies or any applicable law.\xa0\n2.3 Your Security and Backup. You are responsible for properly con\x00guring and using the Services and otherwise taking appropriate action to secure, protect\nand backup your accounts and Your Content in a manner that will provide appropriate security and protection, which might include use of encryption to\nprotect Your Content from unauthorized access and routinely archiving Your Content.\n2.4 Log-In Credentials and Account Keys. AWS log-in credentials and private keys generated by the Services are for your internal use only and you will not sell,\ntransfer or sublicense them to any other entity or person, except that you may disclose your private key to your agents and subcontractors performing work on\nyour behalf.',
#   'your behalf.\n2.5 End Users.\xa0You will be deemed to have taken any action that you permit, assist or facilitate any person or entity to take related to this Agreement, Your\nContent or use of the Services.\xa0You are responsible for End Users’ use of Your Content and the\xa0Services, and for their compliance with your obligations\nunder\xa0this Agreement. If you become aware of any violation of your obligations under this Agreement caused by an End User, you will immediately suspend\naccess to Your Content and the\xa0Services by such End User. We do not provide any support or services to End Users unless we have a separate agreement with\nyou or an End User obligating us to provide such support or services.\xa0\n3. Fees and Payment.\n3.1 Service Fees. We calculate and bill fees and charges monthly. We may bill you more frequently for fees accrued if we reasonably suspect that your account',
#   'is fraudulent or at risk of non-payment. You will pay us the applicable fees and charges for use of the Services as described on the AWS Site using one of the\npayment methods we support. All amounts payable by you under this Agreement will be paid to us without seto\x00 or counterclaim, and without any deduction\nor withholding. Fees and charges for any new Service or new feature of a Service will be e\x00ective when we post updated fees and charges on the AWS Site,\nunless we expressly state otherwise in a notice. We may increase or add new fees and charges for any existing Services you are using by giving you at least 30\ndays’ prior notice. We may elect to charge you interest at the rate of 1.5% per month (or the highest rate permitted by law, if less) on all late payments.\xa0If we\nsuspend your account under Section 4.1 or terminate your use of the Services pursuant to Section 5.2(b)(ii), we may elect not to bill you for fees and charges\nafter suspension unless your account is reinstated.',
#   'after suspension unless your account is reinstated.\n3.2 Taxes.\xa0\n(a) Each party will be responsible, as required under applicable law, for identifying and paying all taxes and other governmental fees and charges (and\nany penalties, interest, and other additions thereto) that are imposed on that party upon or with respect to the transactions and payments under this',
#   'Agreement. All fees payable by you are exclusive of Indirect Taxes, except where applicable law requires otherwise. We may charge and you will pay\napplicable Indirect Taxes that we are legally obligated or authorized to collect from you. You will provide such information to us as reasonably required\nto determine whether we are obligated to collect Indirect Taxes from you. We will not collect, and you will not pay, any Indirect Tax for which you furnish\nus a properly completed exemption certi\x00cate or a direct payment permit certi\x00cate for which we can claim an available exemption from such Indirect\nTax. All payments made by you to us under this Agreement will be made free and clear of any deduction or withholding, as required by law. If any such\ndeduction or withholding (including cross-border withholding taxes) is required on any payment, you will pay such additional amounts as are necessary',
#   'so that the net amount received by us is equal to the amount then due and payable under this Agreement. We will provide you with such tax forms as\nare reasonably requested in order to reduce or eliminate the amount of any withholding or deduction for taxes in respect of payments made under this\nAgreement.\xa0\n(b)\xa0If the applicable AWS Contracting Party is Amazon Web Services India Private Limited ("AWS India") (formerly known as Amazon Internet Services\nPrivate Limited), the parties agree that the provisions of this Section 3.2(b) will apply.\nYou acknowledge that AWS India may display the applicable fees and charges for the Services on the Site in USD (or such other currency as AWS India\nmay deem \x00t). However, AWS India will invoice you in INR calculated and converted in accordance with the conversion rate determined by us on the date\nof invoice ("INR Equivalent Fees"). You will only be liable to pay the INR Equivalent Fees indicated in each invoice.',
#   'We will invoice you from our registered o\x00ce at the address of your establishment (as registered with the tax authorities, if applicable) receiving the\nServices in accordance with the applicable indirect tax laws.\nAll fees and charges payable under this Agreement will be exclusive of applicable national, state or local indirect taxes ("Taxes") that AWS India is legally\nobligated to charge under applicable law. For the purpose of this clause, local indirect taxes include Goods and Services Tax (“GST”), which includes the\nCentral Goods and Services Tax ("CGST"), the State Goods and Services Tax ("SGST"), the Union Territory Goods and Services Tax ("UGST"), the Integrated\nGoods and Services Tax ("IGST") as may be applicable. The Taxes charged by AWS India will be stated in the invoice pursuant to applicable laws. AWS\nIndia may charge and you will pay any applicable Taxes, which are stated separately on the invoice. As per the statutory requirement under GST, you will',
#   'provide all necessary information such as the correct GST registered address, legal name and GSTIN ("GST Information") in order for AWS India to issue\ncorrect GST invoices as per the applicable legal requirements. In the event, the GST invoice is incorrect, you will inform us in a timely manner, to enable\nAWS India to correct the GST tax invoice. AWS India will determine the place of supply for the Services based on the GST Information provided by you\nand accordingly, charge GST (CGST and SGST/UTGST or IGST) on its invoice. Any withholding taxes that may be applicable to the fees and charges\npayable to us are for our account. You will pay the fees and charges in our invoice in full (gross) without applying any withholding taxes. If you separately\ndeposit applicable withholding taxes on such fees and charges to the applicable government treasury and issue us a withholding tax certi\x00cate',
#   'evidencing such deposit, following receipt of the withholding tax certi\x00cate in original form, we will reimburse to you an amount equal to the taxes that\nare evidenced as deposited.\n4. Temporary Suspension.\n4.1 Generally. We may suspend your or any End User’s right to access or use any portion or all of the Services immediately upon notice to you if we\xa0reasonably\ndetermine:\n(a) your or an End User’s use of the Services (i) poses a security risk to the\xa0Services or any third party, (ii) could adversely impact our systems, the\xa0Services\nor the systems or Content of any other AWS customer, (iii) could subject us, our a\x00liates, or any third party to liability, or (iv) could be fraudulent;\n(b) you are, or any End User is, in material breach of this Agreement;\n(c) you are in breach of your payment obligations under Section 3; or\n(d) you have ceased to operate in the ordinary course, made an assignment for the bene\x00t of creditors or similar disposition of your assets, or become',
#   'the subject of any bankruptcy, reorganization, liquidation, dissolution or similar proceeding.\n4.2 E\x00ect of Suspension. If we suspend your right to access or use any portion or all of the Services:\n(a) you will be responsible for all fees and charges you incur during the period of suspension that we bill to you; and\n(b) you will not be entitled to any service credits under the Service Level Agreements for any period of suspension.\xa0\n5. Term; Termination.\n5.1 Term. The term of this Agreement will commence on the E\x00ective Date and will remain in e\x00ect until terminated under this Section 5. Any notice of\ntermination of this Agreement by either party to the other must include a Termination Date that complies with the notice periods in Section 5.2.\n5.2 Termination.\n(a) Termination for Convenience. You may terminate this Agreement for any reason by providing us notice and closing your account for all Services for',
#   'which we provide an account closing mechanism. We may terminate this Agreement for any reason by providing you at least 30 days’ advance notice.',
#   '(b) Termination for Cause.\n(i) By Either Party. Either party may terminate this Agreement for cause if the other party is in material breach of this Agreement and the material\nbreach remains uncured for a period of 30 days from receipt of notice by the other party. No later than the Termination Date, you will close your\naccount.\n(ii) By Us. We may also terminate this Agreement immediately upon notice to you:\n(A) for cause if we have the right to suspend under Section 4\xa0and the issue giving us the right to suspend either:\na.\xa0 is not capable of being remedied; or\nb.\xa0\xa0has not been remedied within 30 days of us suspending your service under Section 4.1;\n(B) if our relationship with a third-party partner who provides software or other technology we use to provide the Services expires,\nterminates or requires us to change the way we provide the software or other technology as part of the Services; or\n(C) in order to comply with the law or requests of governmental entities.',
#   '(C) in order to comply with the law or requests of governmental entities.\n5.3 E\x00ect of Termination.\n(a) Generally. Upon the Termination Date:\n(i) except as provided in Sections 5.3(a)(iv) and 5.3(b), all your rights under this Agreement immediately terminate;\n(ii) you remain responsible for all fees and charges you have incurred through the Termination Date and are responsible for any fees and charges\nyou incur during the post-termination period described in Section 5.3(b) that we bill to you;\n(iii) you will immediately return or, if instructed by us, destroy all AWS Content in your possession; and\n(iv) Sections 2.1, 3, 5.3, 6 (except Section 6.3), 7, 8, 9, 11 and 12 will continue to apply in accordance with their terms.\n(b) Post-Termination. Unless we terminate your use of the Services pursuant to Section 5.2(b), during the 30 days following the Termination Date:',
#   '(i) we will not take action to remove from the AWS systems any of Your Content as a result of the termination; and\n(ii) we will allow you to retrieve Your Content from the Services only if you have paid all amounts due under this Agreement.\nFor any use of the Services after the Termination Date, the terms of this Agreement will apply and you will pay the applicable fees at the rates under Section 3.\n6. Proprietary Rights.\n6.1 Your Content. Except as provided in this Section 6, we obtain no rights under this Agreement from you (or your licensors) to Your Content. You consent to\nour use of Your Content to provide the Services to you and any End Users.\n6.2 Adequate Rights. You represent and warrant to us that: (a) you or your licensors own all right, title, and interest in and to Your Content and Suggestions; (b)\nyou have all rights in Your Content and Suggestions necessary to grant the rights contemplated by this Agreement; and (c) none of Your Content or End Users’',
#   'use of Your Content or the Services will violate the Acceptable Use Policy.\n6.3\xa0Intellectual Property License. The Intellectual Property License applies to your use of AWS Content and the Services.\xa0\n6.4\xa0Restrictions. Neither you nor any End User will use the AWS Content or Services in any manner or for any purpose other than as expressly permitted by this\nAgreement. Neither you nor any End User will, or will attempt to (a) reverse engineer, disassemble, or decompile the Services or AWS Content or apply any\nother process or procedure to derive the source code of any software included in the Services or AWS Content (except to the extent applicable law doesn’t\nallow this restriction), (b) access or use the Services or AWS Content in a way intended to avoid incurring fees or exceeding usage limits or quotas, or (c) resell\nthe Services or AWS Content. The AWS Trademark Guidelines apply to your use of the AWS Marks. You will not misrepresent or embellish the relationship',
#   'between us and you (including by expressing or implying that we support, sponsor, endorse, or contribute to you or your business endeavors). You will not\nimply any relationship or a\x00liation between us and you except as expressly permitted by this Agreement.\n6.5 Suggestions. If you provide any Suggestions to us or our a\x00liates, we and our a\x00liates will be entitled to use the Suggestions without restriction. You\nhereby irrevocably assign to us all right, title, and interest in and to the Suggestions and agree to provide us any assistance we require to document, perfect,\nand maintain our rights in the Suggestions.\xa0\n7. Indemniﬁcation.',
#   '7.1 General. You will defend, indemnify, and hold harmless us, our a\x00liates and licensors, and each of their respective employees, o\x00cers, directors, and\nrepresentatives from and against any Losses arising out of or relating to any third-party claim concerning: (a) your or any End Users’ use of the Services\n(including any activities under your AWS account and use by your employees and personnel); (b) breach of this Agreement or violation of applicable law by you,\nEnd Users or Your Content; or (c) a dispute between you and any End User. You will reimburse us for reasonable attorneys’ fees, as well as our employees’ and\ncontractors’ time and materials spent responding to any third party subpoena or other compulsory legal order or process associated with third party claims\ndescribed in (a) through (c) above at our then-current hourly rates.\n7.2 Intellectual Property.',
#   'described in (a) through (c) above at our then-current hourly rates.\n7.2 Intellectual Property.\n(a) Subject to the limitations in this Section 7, AWS will defend you and your employees, o\x00cers, and directors against any third-party claim alleging\nthat the Services infringe or misappropriate that third party’s intellectual property rights, and will pay the amount of any adverse \x00nal judgment or\nsettlement.\n(b) Subject to the limitations in this Section 7, you will defend AWS, its a\x00liates, and their respective employees, o\x00cers, and directors against any third-\nparty claim alleging that any of Your Content infringes or misappropriates that third party’s intellectual property rights, and will pay the amount of any\nadverse \x00nal judgment or settlement.\n(c) Neither party will have obligations or liability under this Section 7.2 arising from infringement by combinations of the Services or Your Content, as',
#   'applicable, with any other product, service, software, data, content or method. In addition, AWS will have no obligations or liability arising from your or\nany End User’s use of the Services after AWS has noti\x00ed you to discontinue such use. The remedies provided in this Section 7.2 are the sole and\nexclusive remedies for any third-party claims of infringement or misappropriation of intellectual property rights by the Services or by Your Content.\n(d) For any claim covered by Section 7.2(a), AWS will, at its election, either: (i) procure the rights to use that portion of the Services alleged to be\ninfringing; (ii) replace the alleged infringing portion of the Services with a non-infringing alternative; (iii) modify the alleged infringing portion of the\nServices to make it non-infringing; or (iv) terminate the allegedly infringing portion of the Services or this Agreement.',
#   '7.3 Process. The obligations under this Section 7 will apply only if the party seeking defense or indemnity: (a) gives the other party prompt written notice of\nthe claim; (b) permits the other party to control the defense and settlement of the claim; and (c) reasonably cooperates with the other party (at the other\nparty’s expense) in the defense and settlement of the claim. In no event will a party agree to any settlement of any claim that involves any commitment, other\nthan the payment of money, without the written consent of the other party.\xa0\n8. Disclaimers.',
#   'THE SERVICES AND AWS CONTENT ARE PROVIDED “AS IS.” EXCEPT TO THE EXTENT PROHIBITED BY LAW, OR TO THE EXTENT ANY STATUTORY RIGHTS APPLY\nTHAT CANNOT BE EXCLUDED, LIMITED OR WAIVED, WE AND OUR AFFILIATES AND LICENSORS (A) MAKE NO REPRESENTATIONS OR WARRANTIES OF ANY\nKIND, WHETHER EXPRESS, IMPLIED, STATUTORY OR OTHERWISE REGARDING THE\xa0SERVICES OR AWS CONTENT OR THE THIRD-PARTY CONTENT, AND (B)\nDISCLAIM ALL WARRANTIES, INCLUDING ANY IMPLIED OR EXPRESS WARRANTIES (I) OF MERCHANTABILITY, SATISFACTORY QUALITY, FITNESS FOR A\nPARTICULAR PURPOSE, NON-INFRINGEMENT, OR QUIET ENJOYMENT, (II) ARISING OUT OF ANY COURSE OF DEALING OR USAGE OF TRADE, (III) THAT THE\nSERVICES OR AWS CONTENT OR THIRD-PARTY CONTENT WILL BE UNINTERRUPTED, ERROR FREE OR FREE OF HARMFUL COMPONENTS, AND (IV) THAT ANY\nCONTENT WILL BE SECURE OR NOT OTHERWISE LOST OR ALTERED.\xa0\n9. Limitations of Liability.',
#   'CONTENT WILL BE SECURE OR NOT OTHERWISE LOST OR ALTERED.\xa0\n9. Limitations of Liability.\n9.1 Liability Disclaimers. EXCEPT FOR PAYMENT OBLIGATIONS UNDER SECTION 7, NEITHER AWS NOR YOU, NOR ANY OF THEIR AFFILIATES OR LICENSORS,\nWILL HAVE LIABILITY TO THE OTHER UNDER ANY CAUSE OF ACTION OR THEORY OF LIABILITY, EVEN IF A PARTY HAS BEEN ADVISED OF THE POSSIBILITY OF\nSUCH LIABILITY, FOR (A) INDIRECT, INCIDENTAL, SPECIAL, CONSEQUENTIAL OR EXEMPLARY DAMAGES, (B) THE VALUE OF YOUR CONTENT, (C) LOSS OF\nPROFITS, REVENUES, CUSTOMERS, OPPORTUNITIES, OR GOODWILL, OR (D) UNAVAILABILITY OF THE SERVICES OR AWS CONTENT (THIS DOES NOT LIMIT\nANY SERVICE CREDITS UNDER SERVICE LEVEL AGREEMENTS).\n9.2 Damages Cap. EXCEPT FOR PAYMENT OBLIGATIONS UNDER SECTION 7, THE AGGREGATE LIABILITY UNDER THIS AGREEMENT OF EITHER AWS OR YOU,\nAND ANY OF THEIR RESPECTIVE AFFILIATES OR LICENSORS, WILL NOT EXCEED THE AMOUNTS PAID BY YOU TO AWS UNDER THIS AGREEMENT FOR THE',
#   'SERVICES THAT GAVE RISE TO THE LIABILITY DURING THE 12 MONTHS BEFORE THE LIABILITY AROSE; EXCEPT THAT NOTHING IN THIS SECTION 9 WILL LIMIT\nYOUR OBLIGATION TO PAY AWS FOR YOUR USE OF THE SERVICES PURSUANT TO SECTION 3, OR ANY OTHER PAYMENT OBLIGATIONS UNDER THIS\nAGREEMENT.\n10. Modiﬁcations to the Agreement.\nWe may modify this Agreement (including any Policies) at any time by posting a revised version on the AWS Site or by otherwise notifying you in accordance\nwith Section 11.10. The modi\x00ed terms will become e\x00ective upon posting or, if we notify you by email, as stated in the email message. By continuing to use\nthe Services or AWS Content after the e\x00ective date of any modi\x00cations to this Agreement, you agree to be bound by the modi\x00ed terms. It is your\nresponsibility to check the AWS Site regularly for modi\x00cations to this Agreement. We last modi\x00ed this Agreement on the date listed at the\xa0beginning of this\nAgreement.\xa0\n11. Miscellaneous.',
#   '11.1 Assignment. You will not assign or otherwise transfer this Agreement or any of your rights and obligations under this Agreement, without our prior\nwritten consent. Any assignment or transfer in violation of this Section 11.1 will be void. We may assign this Agreement without your consent (a) in connection\nwith a merger, acquisition or sale of all or substantially all of our assets, or (b) to any a\x00liate or as part of a corporate reorganization; and e\x00ective upon such\nassignment, the assignee is deemed substituted for AWS as a party to this Agreement and AWS is fully released from all of its obligations and duties to\nperform under this Agreement. Subject to the foregoing, this Agreement will be binding upon, and inure to the bene\x00t of the parties and their respective\npermitted successors and assigns.\n11.2 Entire Agreement. This Agreement incorporates the Policies by reference and is the entire agreement between you and us regarding the subject matter of',
#   'this Agreement. This Agreement supersedes all prior or contemporaneous representations, understandings, agreements, or communications between you and\nus, whether written or verbal, regarding the subject matter of this Agreement (but does not supersede prior commitments to purchase Services such as\nAmazon EC2 Reserved Instances). None of the parties will be bound by any term, condition or other provision that is di\x00erent from or in addition to the\nprovisions of this Agreement (whether or not it would materially alter this Agreement) including for example, any term, condition or other provision (a)\nsubmitted by you in any order, receipt, acceptance, con\x00rmation, correspondence or other document, (b) related to any online registration, response to any\nRequest for Bid, Request for Proposal, Request for Information, or other questionnaire, or (c) related to any invoicing process that you submit or require us to',
#   'complete. If the terms of this document are inconsistent with the terms contained in any Policy, the terms contained in this document will control, except that\nthe Service Terms will control over this document.\n11.3 Force Majeure. Except for payment obligations, neither party nor any of their a\x00liates will be liable for any delay or failure to perform any obligation\nunder this Agreement where the delay or failure results from any cause beyond its reasonable control, including acts of God, labor disputes or other industrial\ndisturbances, electrical or power outages, utilities or other telecommunications failures, earthquake, storms or other elements of nature, blockages,\nembargoes, riots, acts or orders of government, acts of terrorism, or war.\n11.4 Governing Law. The Governing Laws, without reference to con\x00ict of law rules, govern this Agreement and any dispute of any sort that might arise',
#   'between you and us. The United Nations Convention for the International Sale of Goods does not apply to this Agreement.\n11.5 Disputes. Any dispute or claim relating in any way to your use of the Services, or to any products or services sold or distributed by AWS will be adjudicated\nin the Governing Courts, and you consent to exclusive jurisdiction and venue in the Governing Courts, subject to the additional provisions below.\n(a)\xa0If the applicable AWS Contracting Party is Amazon Web Services, Inc., Amazon Web Services Canada, Inc., Amazon Web Services Korea LLC or Amazon\nWeb Services Singapore Private Limited, the parties agree that the provisions of this Section 11.5(a) will apply. Disputes will be resolved by binding\narbitration, rather than in court, except that either party may elect to proceed in small claims court if your claims qualify. The Federal Arbitration Act and',
#   'federal arbitration law apply to this Agreement, except that if Amazon Web Services Canada, Inc. is the applicable AWS Contracting Party the Ontario',
#   'Arbitration Act will apply to this Agreement. There is no judge or jury in arbitration, and court review of an arbitration award is limited. However, an\narbitrator can award the same damages and relief as a court (including injunctive and declaratory relief or statutory damages), and must follow the\nterms of this Agreement as a court would. Before you may begin an arbitration proceeding, you must send a letter notifying us of your intent to pursue\narbitration and describing your claim to our registered agent Corporation Service Company, 300 Deschutes Way SW, Suite 304, Tumwater, WA 98501.\nThe arbitration will be conducted by the American Arbitration Association (AAA) under its commercial rules, which are available at www.adr.org or by\ncalling 1-800-778-7879. Payment of \x00ling, administration and arbitrator fees will be governed by the AAA commercial fee schedule. We and you agree',
#   'that any dispute resolution proceedings will be conducted only on an individual basis and not in a class, consolidated or representative action.\xa0We and\nyou further agree that the underlying award in arbitration may be appealed pursuant to the AAA’s Optional Appellate Arbitration Rules. If for any reason\na claim proceeds in court rather than in arbitration we and you waive any right to a jury trial. Notwithstanding the foregoing we and you both agree that\nyou or we may bring suit in court to enjoin infringement or other misuse of intellectual property rights.\n(b) If the applicable AWS Contracting Party is Amazon Web Services South Africa Proprietary Limited, the parties agree that the provisions of this Section\n11.5(b) will apply. Disputes will be resolved by arbitration in accordance with the then-applicable rules of the Arbitration Foundation of Southern Africa,',
#   'and judgment on the arbitral award must be entered in the Governing Court. The Arbitration Act, No. 42 of 1965 applies to this Agreement. The\narbitration will take place in Johannesburg. There will be three arbitrators. The fees and expenses of the arbitrators and the administering authority, if\nany, will be paid in equal proportion by the parties.\n(c)\xa0If the applicable AWS Contracting Party is Amazon AWS Serviços Brasil Ltda., the parties agree that the provisions of this Section 11.5(c) will\napply. Disputes will be resolved by binding arbitration, rather than in court, in accordance with the then-applicable Rules of Arbitration of the\nInternational Chamber of Commerce, and judgment on the arbitral award may be entered in any court having jurisdiction. The arbitration will take\nplace in the City of São Paulo, State of São Paulo, Brazil. There will be three arbitrators. The fees and expenses of the arbitrators and the',
# ...
#   {'page': 0, 'source': 'AWS Service Terms.pdf'},
#   {'page': 0, 'source': 'AWS Service Terms.pdf'},
#   {'page': 1, 'source': 'AWS Service Terms.pdf'},
#   {'page': 1, 'source': 'AWS Service Terms.pdf'},
#   {'page': 1, 'source': 'AWS Service Terms.pdf'},
#   {'page': 1, 'source': 'AWS Service Terms.pdf'},
#   {'page': 2, 'source': 'AWS Service Terms.pdf'},
#   {'page': 2, 'source': 'AWS Service Terms.pdf'},
#   {'page': 2, 'source': 'AWS Service Terms.pdf'},
#   {'page': 2, 'source': 'AWS Service Terms.pdf'},
#   {'page': 3, 'source': 'AWS Service Terms.pdf'},
#   {'page': 3, 'source': 'AWS Service Terms.pdf'},
#   {'page': 3, 'source': 'AWS Service Terms.pdf'},
#   {'page': 4, 'source': 'AWS Service Terms.pdf'},
#   {'page': 4, 'source': 'AWS Service Terms.pdf'},
#   {'page': 4, 'source': 'AWS Service Terms.pdf'},
#   {'page': 5, 'source': 'AWS Service Terms.pdf'},
#   {'page': 5, 'source': 'AWS Service Terms.pdf'},
#   {'page': 5, 'source': 'AWS Service Terms.pdf'},
#   {'page': 5, 'source': 'AWS Service Terms.pdf'},
#   {'page': 6, 'source': 'AWS Service Terms.pdf'},
#   {'page': 6, 'source': 'AWS Service Terms.pdf'},
#   {'page': 6, 'source': 'AWS Service Terms.pdf'},
#   {'page': 6, 'source': 'AWS Service Terms.pdf'},
#   {'page': 7, 'source': 'AWS Service Terms.pdf'},
#   {'page': 7, 'source': 'AWS Service Terms.pdf'},
#   {'page': 7, 'source': 'AWS Service Terms.pdf'},
#   {'page': 7, 'source': 'AWS Service Terms.pdf'},
#   {'page': 8, 'source': 'AWS Service Terms.pdf'},
#   {'page': 8, 'source': 'AWS Service Terms.pdf'},
#   {'page': 8, 'source': 'AWS Service Terms.pdf'},
#   {'page': 9, 'source': 'AWS Service Terms.pdf'},
#   {'page': 9, 'source': 'AWS Service Terms.pdf'},
#   {'page': 9, 'source': 'AWS Service Terms.pdf'},
#   {'page': 9, 'source': 'AWS Service Terms.pdf'},
#   {'page': 10, 'source': 'AWS Service Terms.pdf'},
#   {'page': 10, 'source': 'AWS Service Terms.pdf'},
#   {'page': 10, 'source': 'AWS Service Terms.pdf'},
#   {'page': 10, 'source': 'AWS Service Terms.pdf'},
#   {'page': 10, 'source': 'AWS Service Terms.pdf'},
#   {'page': 11, 'source': 'AWS Service Terms.pdf'},
#   {'page': 11, 'source': 'AWS Service Terms.pdf'},
#   {'page': 11, 'source': 'AWS Service Terms.pdf'},
#   {'page': 11, 'source': 'AWS Service Terms.pdf'},
#   {'page': 12, 'source': 'AWS Service Terms.pdf'},
#   {'page': 12, 'source': 'AWS Service Terms.pdf'},
#   {'page': 12, 'source': 'AWS Service Terms.pdf'},
#   {'page': 12, 'source': 'AWS Service Terms.pdf'},
#   {'page': 12, 'source': 'AWS Service Terms.pdf'},
#   {'page': 13, 'source': 'AWS Service Terms.pdf'},
#   {'page': 13, 'source': 'AWS Service Terms.pdf'},
#   {'page': 13, 'source': 'AWS Service Terms.pdf'},
#   {'page': 14, 'source': 'AWS Service Terms.pdf'},
#   {'page': 14, 'source': 'AWS Service Terms.pdf'},
#   {'page': 14, 'source': 'AWS Service Terms.pdf'},
#   {'page': 14, 'source': 'AWS Service Terms.pdf'},
#   {'page': 15, 'source': 'AWS Service Terms.pdf'},
#   {'page': 15, 'source': 'AWS Service Terms.pdf'},
#   {'page': 15, 'source': 'AWS Service Terms.pdf'},
#   {'page': 15, 'source': 'AWS Service Terms.pdf'},
#   {'page': 16, 'source': 'AWS Service Terms.pdf'},
#   {'page': 16, 'source': 'AWS Service Terms.pdf'},
#   {'page': 16, 'source': 'AWS Service Terms.pdf'},
#   {'page': 16, 'source': 'AWS Service Terms.pdf'},
#   {'page': 17, 'source': 'AWS Service Terms.pdf'},
#   {'page': 17, 'source': 'AWS Service Terms.pdf'},
#   {'page': 17, 'source': 'AWS Service Terms.pdf'},
#   {'page': 18, 'source': 'AWS Service Terms.pdf'},
#   {'page': 18, 'source': 'AWS Service Terms.pdf'},
#   {'page': 18, 'source': 'AWS Service Terms.pdf'},
#   {'page': 18, 'source': 'AWS Service Terms.pdf'},
#   {'page': 19, 'source': 'AWS Service Terms.pdf'},
#   {'page': 19, 'source': 'AWS Service Terms.pdf'},
#   {'page': 19, 'source': 'AWS Service Terms.pdf'},
#   {'page': 20, 'source': 'AWS Service Terms.pdf'},
#   {'page': 20, 'source': 'AWS Service Terms.pdf'},
#   {'page': 20, 'source': 'AWS Service Terms.pdf'},
#   {'page': 21, 'source': 'AWS Service Terms.pdf'},
#   {'page': 21, 'source': 'AWS Service Terms.pdf'},
#   {'page': 21, 'source': 'AWS Service Terms.pdf'},
#   {'page': 22, 'source': 'AWS Service Terms.pdf'},
#   {'page': 22, 'source': 'AWS Service Terms.pdf'},
#   {'page': 22, 'source': 'AWS Service Terms.pdf'},
#   {'page': 23, 'source': 'AWS Service Terms.pdf'},
#   {'page': 23, 'source': 'AWS Service Terms.pdf'},
#   {'page': 23, 'source': 'AWS Service Terms.pdf'},
#   {'page': 24, 'source': 'AWS Service Terms.pdf'},
#   {'page': 24, 'source': 'AWS Service Terms.pdf'},
#   {'page': 24, 'source': 'AWS Service Terms.pdf'},
#   {'page': 24, 'source': 'AWS Service Terms.pdf'},
#   {'page': 25, 'source': 'AWS Service Terms.pdf'},
#   {'page': 25, 'source': 'AWS Service Terms.pdf'},
#   {'page': 26, 'source': 'AWS Service Terms.pdf'},
#   {'page': 26, 'source': 'AWS Service Terms.pdf'},
#   {'page': 26, 'source': 'AWS Service Terms.pdf'},
#   {'page': 26, 'source': 'AWS Service Terms.pdf'},
#   {'page': 27, 'source': 'AWS Service Terms.pdf'},
#   {'page': 27, 'source': 'AWS Service Terms.pdf'},
#   {'page': 27, 'source': 'AWS Service Terms.pdf'},
#   {'page': 27, 'source': 'AWS Service Terms.pdf'},
#   {'page': 28, 'source': 'AWS Service Terms.pdf'},
#   {'page': 28, 'source': 'AWS Service Terms.pdf'},
#   {'page': 28, 'source': 'AWS Service Terms.pdf'},
#   {'page': 29, 'source': 'AWS Service Terms.pdf'},
#   {'page': 29, 'source': 'AWS Service Terms.pdf'},
#   {'page': 29, 'source': 'AWS Service Terms.pdf'},
#   {'page': 30, 'source': 'AWS Service Terms.pdf'},
#   {'page': 30, 'source': 'AWS Service Terms.pdf'},
#   {'page': 30, 'source': 'AWS Service Terms.pdf'},
#   {'page': 31, 'source': 'AWS Service Terms.pdf'},
#   {'page': 31, 'source': 'AWS Service Terms.pdf'},
#   {'page': 31, 'source': 'AWS Service Terms.pdf'},
#   {'page': 32, 'source': 'AWS Service Terms.pdf'},
#   {'page': 32, 'source': 'AWS Service Terms.pdf'},
#   {'page': 32, 'source': 'AWS Service Terms.pdf'},
#   {'page': 33, 'source': 'AWS Service Terms.pdf'},
#   {'page': 33, 'source': 'AWS Service Terms.pdf'},
#   {'page': 33, 'source': 'AWS Service Terms.pdf'},
#   {'page': 34, 'source': 'AWS Service Terms.pdf'},
#   {'page': 34, 'source': 'AWS Service Terms.pdf'},
#   {'page': 34, 'source': 'AWS Service Terms.pdf'},
#   {'page': 35, 'source': 'AWS Service Terms.pdf'},
#   {'page': 35, 'source': 'AWS Service Terms.pdf'},
#   {'page': 35, 'source': 'AWS Service Terms.pdf'},
#   {'page': 36, 'source': 'AWS Service Terms.pdf'},
#   {'page': 36, 'source': 'AWS Service Terms.pdf'},
#   {'page': 36, 'source': 'AWS Service Terms.pdf'},
#   {'page': 36, 'source': 'AWS Service Terms.pdf'},
#   {'page': 37, 'source': 'AWS Service Terms.pdf'},
#   {'page': 37, 'source': 'AWS Service Terms.pdf'},
#   {'page': 37, 'source': 'AWS Service Terms.pdf'},
#   {'page': 37, 'source': 'AWS Service Terms.pdf'},
#   {'page': 38, 'source': 'AWS Service Terms.pdf'},
#   {'page': 38, 'source': 'AWS Service Terms.pdf'},
#   {'page': 38, 'source': 'AWS Service Terms.pdf'},
#   {'page': 38, 'source': 'AWS Service Terms.pdf'},
#   {'page': 39, 'source': 'AWS Service Terms.pdf'},
#   {'page': 39, 'source': 'AWS Service Terms.pdf'},
#   {'page': 39, 'source': 'AWS Service Terms.pdf'},
#   {'page': 39, 'source': 'AWS Service Terms.pdf'},
#   {'page': 40, 'source': 'AWS Service Terms.pdf'},
#   {'page': 40, 'source': 'AWS Service Terms.pdf'},
#   {'page': 40, 'source': 'AWS Service Terms.pdf'},
#   {'page': 41, 'source': 'AWS Service Terms.pdf'},
#   {'page': 41, 'source': 'AWS Service Terms.pdf'},
#   {'page': 41, 'source': 'AWS Service Terms.pdf'},
#   {'page': 42, 'source': 'AWS Service Terms.pdf'},
#   {'page': 42, 'source': 'AWS Service Terms.pdf'},
#   {'page': 42, 'source': 'AWS Service Terms.pdf'},
#   {'page': 42, 'source': 'AWS Service Terms.pdf'},
#   {'page': 43, 'source': 'AWS Service Terms.pdf'},
#   {'page': 43, 'source': 'AWS Service Terms.pdf'},
#   {'page': 43, 'source': 'AWS Service Terms.pdf'},
#   {'page': 43, 'source': 'AWS Service Terms.pdf'},
#   {'page': 44, 'source': 'AWS Service Terms.pdf'},
#   {'page': 44, 'source': 'AWS Service Terms.pdf'},
#   {'page': 44, 'source': 'AWS Service Terms.pdf'},
#   {'page': 44, 'source': 'AWS Service Terms.pdf'},
#   {'page': 45, 'source': 'AWS Service Terms.pdf'},
#   {'page': 45, 'source': 'AWS Service Terms.pdf'},
#   {'page': 45, 'source': 'AWS Service Terms.pdf'},
#   {'page': 45, 'source': 'AWS Service Terms.pdf'},
#   {'page': 46, 'source': 'AWS Service Terms.pdf'},
#   {'page': 46, 'source': 'AWS Service Terms.pdf'},
#   {'page': 46, 'source': 'AWS Service Terms.pdf'},
#   {'page': 46, 'source': 'AWS Service Terms.pdf'},
#   {'page': 47, 'source': 'AWS Service Terms.pdf'},
#   {'page': 47, 'source': 'AWS Service Terms.pdf'},
#   {'page': 47, 'source': 'AWS Service Terms.pdf'},
#   {'page': 47, 'source': 'AWS Service Terms.pdf'},
#   {'page': 47, 'source': 'AWS Service Terms.pdf'},
#   {'page': 48, 'source': 'AWS Service Terms.pdf'},
#   {'page': 48, 'source': 'AWS Service Terms.pdf'},
#   {'page': 48, 'source': 'AWS Service Terms.pdf'},
#   {'page': 48, 'source': 'AWS Service Terms.pdf'},
#   {'page': 49, 'source': 'AWS Service Terms.pdf'},
#   {'page': 49, 'source': 'AWS Service Terms.pdf'},
#   {'page': 49, 'source': 'AWS Service Terms.pdf'},
#   {'page': 49, 'source': 'AWS Service Terms.pdf'},
#   {'page': 49, 'source': 'AWS Service Terms.pdf'},
#   {'page': 50, 'source': 'AWS Service Terms.pdf'},
#   {'page': 50, 'source': 'AWS Service Terms.pdf'},
#   {'page': 50, 'source': 'AWS Service Terms.pdf'},
#   {'page': 50, 'source': 'AWS Service Terms.pdf'},
#   {'page': 51, 'source': 'AWS Service Terms.pdf'},
#   {'page': 51, 'source': 'AWS Service Terms.pdf'},
#   {'page': 51, 'source': 'AWS Service Terms.pdf'},
#   {'page': 52, 'source': 'AWS Service Terms.pdf'},
#   {'page': 52, 'source': 'AWS Service Terms.pdf'},
#   {'page': 52, 'source': 'AWS Service Terms.pdf'},
#   {'page': 52, 'source': 'AWS Service Terms.pdf'},
#   {'page': 52, 'source': 'AWS Service Terms.pdf'},
#   {'page': 53, 'source': 'AWS Service Terms.pdf'},
#   {'page': 53, 'source': 'AWS Service Terms.pdf'},
#   {'page': 53, 'source': 'AWS Service Terms.pdf'},
#   {'page': 53, 'source': 'AWS Service Terms.pdf'},
#   {'page': 54, 'source': 'AWS Service Terms.pdf'},
#   {'page': 54, 'source': 'AWS Service Terms.pdf'},
#   {'page': 54, 'source': 'AWS Service Terms.pdf'},
#   {'page': 54, 'source': 'AWS Service Terms.pdf'},
#   {'page': 55, 'source': 'AWS Service Terms.pdf'},
#   {'page': 55, 'source': 'AWS Service Terms.pdf'},
#   {'page': 55, 'source': 'AWS Service Terms.pdf'},
#   {'page': 56, 'source': 'AWS Service Terms.pdf'},
#   {'page': 56, 'source': 'AWS Service Terms.pdf'},
#   {'page': 56, 'source': 'AWS Service Terms.pdf'},
#   {'page': 56, 'source': 'AWS Service Terms.pdf'},
#   {'page': 57, 'source': 'AWS Service Terms.pdf'},
#   {'page': 57, 'source': 'AWS Service Terms.pdf'},
#   {'page': 57, 'source': 'AWS Service Terms.pdf'},
#   {'page': 57, 'source': 'AWS Service Terms.pdf'},
#   {'page': 58, 'source': 'AWS Service Terms.pdf'},
#   {'page': 58, 'source': 'AWS Service Terms.pdf'},
#   {'page': 58, 'source': 'AWS Service Terms.pdf'},
#   {'page': 59, 'source': 'AWS Service Terms.pdf'},
#   {'page': 59, 'source': 'AWS Service Terms.pdf'},
#   {'page': 59, 'source': 'AWS Service Terms.pdf'},
#   {'page': 60, 'source': 'AWS Service Terms.pdf'},
#   {'page': 60, 'source': 'AWS Service Terms.pdf'},
#   {'page': 60, 'source': 'AWS Service Terms.pdf'},
#   {'page': 61, 'source': 'AWS Service Terms.pdf'},
#   {'page': 61, 'source': 'AWS Service Terms.pdf'},
#   {'page': 61, 'source': 'AWS Service Terms.pdf'},
#   {'page': 61, 'source': 'AWS Service Terms.pdf'},
#   {'page': 62, 'source': 'AWS Service Terms.pdf'},
#   {'page': 62, 'source': 'AWS Service Terms.pdf'},
#   {'page': 63, 'source': 'AWS Service Terms.pdf'},
#   {'page': 63, 'source': 'AWS Service Terms.pdf'},
#   {'page': 63, 'source': 'AWS Service Terms.pdf'},
#   {'page': 64, 'source': 'AWS Service Terms.pdf'},
#   {'page': 64, 'source': 'AWS Service Terms.pdf'},
#   {'page': 64, 'source': 'AWS Service Terms.pdf'},
#   {'page': 65, 'source': 'AWS Service Terms.pdf'},
#   {'page': 65, 'source': 'AWS Service Terms.pdf'},
#   {'page': 65, 'source': 'AWS Service Terms.pdf'},
#   {'page': 65, 'source': 'AWS Service Terms.pdf'},
#   {'page': 66, 'source': 'AWS Service Terms.pdf'},
#   {'page': 66, 'source': 'AWS Service Terms.pdf'},
#   {'page': 66, 'source': 'AWS Service Terms.pdf'},
#   {'page': 66, 'source': 'AWS Service Terms.pdf'},
#   {'page': 67, 'source': 'AWS Service Terms.pdf'},
#   {'page': 67, 'source': 'AWS Service Terms.pdf'},
#   {'page': 67, 'source': 'AWS Service Terms.pdf'},
#   {'page': 67, 'source': 'AWS Service Terms.pdf'},
#   {'page': 68, 'source': 'AWS Service Terms.pdf'},
#   {'page': 68, 'source': 'AWS Service Terms.pdf'},
#   {'page': 68, 'source': 'AWS Service Terms.pdf'},
#   {'page': 68, 'source': 'AWS Service Terms.pdf'},
#   {'page': 69, 'source': 'AWS Service Terms.pdf'},
#   {'page': 69, 'source': 'AWS Service Terms.pdf'},
#   {'page': 69, 'source': 'AWS Service Terms.pdf'},
#   {'page': 70, 'source': 'AWS Service Terms.pdf'},
#   {'page': 70, 'source': 'AWS Service Terms.pdf'},
#   {'page': 70, 'source': 'AWS Service Terms.pdf'},
#   {'page': 70, 'source': 'AWS Service Terms.pdf'},
#   {'page': 71, 'source': 'AWS Service Terms.pdf'},
#   {'page': 71, 'source': 'AWS Service Terms.pdf'},
#   {'page': 71, 'source': 'AWS Service Terms.pdf'},
#   {'page': 72, 'source': 'AWS Service Terms.pdf'},
#   {'page': 72, 'source': 'AWS Service Terms.pdf'},
#   {'page': 72, 'source': 'AWS Service Terms.pdf'},
#   {'page': 73, 'source': 'AWS Service Terms.pdf'},
#   {'page': 73, 'source': 'AWS Service Terms.pdf'},
#   {'page': 73, 'source': 'AWS Service Terms.pdf'},
#   {'page': 73, 'source': 'AWS Service Terms.pdf'},
#   {'page': 74, 'source': 'AWS Service Terms.pdf'},
#   {'page': 74, 'source': 'AWS Service Terms.pdf'},
#   {'page': 74, 'source': 'AWS Service Terms.pdf'},
#   {'page': 75, 'source': 'AWS Service Terms.pdf'},
#   {'page': 75, 'source': 'AWS Service Terms.pdf'},
#   {'page': 75, 'source': 'AWS Service Terms.pdf'},
#   {'page': 76, 'source': 'AWS Service Terms.pdf'},
#   {'page': 76, 'source': 'AWS Service Terms.pdf'},
#   {'page': 76, 'source': 'AWS Service Terms.pdf'},
#   {'page': 77, 'source': 'AWS Service Terms.pdf'},
#   {'page': 77, 'source': 'AWS Service Terms.pdf'},
#   {'page': 77, 'source': 'AWS Service Terms.pdf'},
#   {'page': 78, 'source': 'AWS Service Terms.pdf'},
#   {'page': 78, 'source': 'AWS Service Terms.pdf'},
#   {'page': 78, 'source': 'AWS Service Terms.pdf'},
#   {'page': 79, 'source': 'AWS Service Terms.pdf'},
#   {'page': 79, 'source': 'AWS Service Terms.pdf'},
#   {'page': 79, 'source': 'AWS Service Terms.pdf'},
#   {'page': 79, 'source': 'AWS Service Terms.pdf'},
#   {'page': 80, 'source': 'AWS Service Terms.pdf'},
#   {'page': 80, 'source': 'AWS Service Terms.pdf'},
#   {'page': 80, 'source': 'AWS Service Terms.pdf'},
#   {'page': 81, 'source': 'AWS Service Terms.pdf'},
#   {'page': 81, 'source': 'AWS Service Terms.pdf'},
#   {'page': 81, 'source': 'AWS Service Terms.pdf'},
#   {'page': 81, 'source': 'AWS Service Terms.pdf'},
#   {'page': 82, 'source': 'AWS Service Terms.pdf'},
#   {'page': 82, 'source': 'AWS Service Terms.pdf'},
#   {'page': 82, 'source': 'AWS Service Terms.pdf'},
#   {'page': 83, 'source': 'AWS Service Terms.pdf'},
#   {'page': 83, 'source': 'AWS Service Terms.pdf'},
#   {'page': 83, 'source': 'AWS Service Terms.pdf'},
#   {'page': 84, 'source': 'AWS Service Terms.pdf'},
#   {'page': 84, 'source': 'AWS Service Terms.pdf'},
#   {'page': 84, 'source': 'AWS Service Terms.pdf'},
#   {'page': 84, 'source': 'AWS Service Terms.pdf'},
#   {'page': 84, 'source': 'AWS Service Terms.pdf'},
#   {'page': 85, 'source': 'AWS Service Terms.pdf'},
#   {'page': 85, 'source': 'AWS Service Terms.pdf'},
#   {'page': 85, 'source': 'AWS Service Terms.pdf'},
#   {'page': 85, 'source': 'AWS Service Terms.pdf'},
#   {'page': 86, 'source': 'AWS Service Terms.pdf'},
#   {'page': 86, 'source': 'AWS Service Terms.pdf'},
#   {'page': 86, 'source': 'AWS Service Terms.pdf'},
#   {'page': 87, 'source': 'AWS Service Terms.pdf'},
#   {'page': 88, 'source': 'AWS Service Terms.pdf'},
#   {'page': 89, 'source': 'AWS Service Terms.pdf'}],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a virtual chat assistant for answering AWS customer and AWS service agreement questions. Answer the question based on the given context. If you don't know the answer, just say you don't know and don't make up an answer. The answer needs to be factual and based on the context given."),
    MessagesPlaceholder(variable_name="context"),
    ("user", "{question}")
])

# %%
llm = ChatOpenAI(
    model = "gpt-3.5-turbo",
    temperature=0.2,
    api_key="",
    max_retries=2,
    max_tokens=None
)

# %%
embeddings = NVIDIAEmbeddings(
                model="nvidia/nv-embedqa-mistral-7b-v2", 
                api_key="", 
                truncate="NONE", 
                )

vectordb = Chroma(
    persist_directory=CHROMA_PATH,
    embedding_function=embeddings
)

doc_count = vectordb._collection.count()
print(f"Vector store contains {doc_count} documents.")

retriever = vectordb.as_retriever()
# Out:
# Vector store contains 0 documents.

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = RunnableMap({
    "context": retriever,
    "question": RunnablePassthrough()
}) | prompt | llm | StrOutputParser()

# %%
query = "What is Amazon Fraud Detector terms mentioned in service terms?"

retrieved_docs = retriever.invoke(query)
print(f"Retrieved {len(retrieved_docs)} documents")
# Out:
# Retrieved 0 documents

# %%
for doc in retrieved_docs:
    print(doc.metadata['source'])
    print(doc.page_content[:200])

# %%
result = rag_chain.invoke(query)

print("Answer:", result)
# Out:
# Answer: Amazon Fraud Detector is a fully managed service that makes it easy to identify potentially fraudulent online activities such as online payment fraud and the creation of fake accounts. The terms related to Amazon Fraud Detector can be found in the AWS Service Terms. These terms outline the usage policies, pricing, data protection, and other important information related to using Amazon Fraud Detector within the AWS environment. For specific details, it is recommended to refer to the AWS Service Terms documentation for Amazon Fraud Detector.
