# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'results.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#                      question          embedding_model      llm_model  \
# 0  what are aws service terms  paraphrase-multilingual  llama2:latest
# 1  what are aws service terms  paraphrase-multilingual  gpt-3.5-turbo
# 2  what are aws service terms  paraphrase-multilingual       gemma:2b
# 3  what are aws service terms               all-minilm  llama2:latest
# 4  what are aws service terms   text-embedding-3-large  llama2:latest
#
#                                               answer  grading_model  score  \
# 0  The AWS Service Terms refer to the agreements ...  gpt-3.5-turbo    0.0
# 1  AWS service terms refer to the specific terms ...  gpt-3.5-turbo    1.0
# 2  Sure, here's the answer to the question:\n\nWh...  gpt-3.5-turbo    1.0
# 3  The AWS Service Terms refer to the agreements ...  gpt-3.5-turbo    0.0
# 4  AWS (Amazon Web Services) provides a wide rang...  gpt-3.5-turbo    1.0
#
#                                          explanation
# ...

# %%
embedding_scores = data.groupby("embedding_model")["score"].mean().reset_index(name="average_score")
llm_scores = data.groupby("llm_model")["score"].mean().reset_index(name="average_score")

plt.figure(figsize=(10, 6))
sns.barplot(x="average_score", y="embedding_model", data=embedding_scores)
plt.title("Average Score by Embedding Model")
plt.xlabel("Average Score")
plt.ylabel("Embedding Model")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="average_score", y="llm_model", data=llm_scores)
plt.title("Average Score by LLM Model")
plt.xlabel("Average Score")
plt.ylabel("LLM Model")
plt.tight_layout()
plt.show()
